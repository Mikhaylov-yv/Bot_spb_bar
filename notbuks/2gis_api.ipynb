# %%
# Ту гис
# import dgis
# googlemaps
import googlemaps
from datetime import datetime
import pandas as pd

# %%
import sys
sys.path.insert(0, "../bot")
import bot_data
import bar_serch

# %%
gmaps = googlemaps.Client(key = bot_data.google_token)

data = gmaps.places(type = "bar", location = (60.02987327010727, 30.41587002010728), radius = 500, language = 'ru')

# %%
df = pd.json_normalize(data['results'])
df.head()
# Out:
#   business_status                                  formatted_address  \
# 0     OPERATIONAL       Учительская ул., 18, Санкт-Петербург, 195269
# 1     OPERATIONAL         ул. Руставели, 66, Санкт-Петербург, 195299
# 2     OPERATIONAL   Граждaнский пр-т., 100Б, Санкт-Петербург, 195265
# 3     OPERATIONAL  пр. Просвещения, 76, к.1, Санкт-Петербург, 195297
# 4     OPERATIONAL     Граждaнский пр-т., 84, Санкт-Петербург, 195257
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                                 name  \
# 0                                 Пиf'ko street food
# 1                                        Бар Элегант
# 2                                            Трибуна
# ...

# %%
df = df[['name','formatted_address', 
             'rating', 'types', 'user_ratings_total', 
             'opening_hours.open_now',
            'geometry.location.lat', 'geometry.location.lng']]

# %%
mes = ''
for i, ind in enumerate(df.sort_values('user_ratings_total', ascending = False)[:5].index):
    mes += f"{i}. {df.loc[ind, 'name']}\n"
print(mes)
# Out:
# 0. BBQ
# 1. Евразия
# 2. Golden Pub
# 3. Трибуна
# 4. The Templet Bar

# %%
serch = bar_serch.Bar_serch((30.419383,60.03081))
# Out:
# (30.419383, 60.03081)
