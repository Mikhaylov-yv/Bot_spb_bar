# %%
# Ту гис
# import dgis
# googlemaps
import googlemaps
from datetime import datetime
import pandas as pd

# %%
import sys
sys.path.insert(0, "../bot_app")
import bot_data
import bar_serch

# %%
gmaps = googlemaps.Client(key = bot_data.google_token)

data = gmaps.places(type = "bar", location = (60.02987327010727, 30.41587002010728), radius = 500, language = 'ru')

# %%
str(type(None)) == "<class 'NoneType'>"
# Out:
# False

# %%
df = pd.json_normalize(data['results'])
df.head()
# Out:
#   business_status                                  formatted_address  \
# 0     OPERATIONAL           гражданский 119, Санкт-Петербург, 195267
# 1     OPERATIONAL       Учительская ул., 18, Санкт-Петербург, 195269
# 2     OPERATIONAL         ул. Руставели, 66, Санкт-Петербург, 195299
# 3     OPERATIONAL   Граждaнский пр-т., 100Б, Санкт-Петербург, 195265
# 4     OPERATIONAL  пр. Просвещения, 76, к.1, Санкт-Петербург, 195297
#
#                                                 icon                name  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...  Feromon Grazhdanka
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...  Пиf'ko street food
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...         Бар Элегант
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...             Трибуна
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...     The Templet Bar
#
#                                               photos  \
# 0  [{'height': 854, 'html_attributions': ['<a hre...
# 1  [{'height': 3024, 'html_attributions': ['<a hr...
# 2  [{'height': 1960, 'html_attributions': ['<a hr...
# 3  [{'height': 3073, 'html_attributions': ['<a hr...
# 4  [{'height': 2988, 'html_attributions': ['<a hr...
#
#                       place_id  price_level  rating  \
# 0  ChIJMcDmjUczlkYRR5iASDNGibU          2.0     4.0
# 1  ChIJkdG-aUIzlkYR14Qn8AbpAuY          2.0     4.1
# 2  ChIJpV09Rj8zlkYRvAeSmjInDdA          NaN     4.6
# 3  ChIJUUjwZ5AxlkYRVReGpqP2WqM          2.0     4.5
# 4  ChIJvSbdZlkzlkYRQE5jPUv9WVg          2.0     4.4
#
#                      reference  \
# 0  ChIJMcDmjUczlkYRR5iASDNGibU
# 1  ChIJkdG-aUIzlkYR14Qn8AbpAuY
# 2  ChIJpV09Rj8zlkYRvAeSmjInDdA
# 3  ChIJUUjwZ5AxlkYRVReGpqP2WqM
# 4  ChIJvSbdZlkzlkYRQE5jPUv9WVg
#
#                                                types  user_ratings_total  \
# 0  [movie_theater, night_club, cafe, bar, restaur...                 415
# 1  [bar, cafe, food, point_of_interest, establish...                  60
# 2            [bar, point_of_interest, establishment]                  96
# 3  [restaurant, bar, food, point_of_interest, est...                 606
# 4  [bar, restaurant, food, point_of_interest, est...                 407
#
#    geometry.location.lat  geometry.location.lng  \
# 0              60.033868              30.420680
# 1              60.032029              30.405459
# 2              60.037469              30.430666
# 3              60.023930              30.403810
# 4              60.041360              30.393235
#
#    geometry.viewport.northeast.lat  geometry.viewport.northeast.lng  \
# 0                        60.035166                        30.421979
# 1                        60.033303                        30.407089
# 2                        60.038644                        30.431878
# 3                        60.025261                        30.405145
# 4                        60.042598                        30.394492
#
#    geometry.viewport.southwest.lat  geometry.viewport.southwest.lng  \
# 0                        60.032467                        30.419279
# 1                        60.030603                        30.404389
# 2                        60.035945                        30.429179
# 3                        60.022562                        30.402445
# 4                        60.039898                        30.391792
#
#    opening_hours.open_now                   plus_code.compound_code  \
# 0                    True  2CMC+G7 Калининский р-н, Санкт-Петербург
# 1                    True  2CJ4+R5 Калининский р-н, Санкт-Петербург
# 2                    True  2CPJ+X7 Калининский р-н, Санкт-Петербург
# 3                    True  2CF3+HG Калининский р-н, Санкт-Петербург
# 4                    True  29RV+G7 Калининский р-н, Санкт-Петербург
#
#   plus_code.global_code
# 0           9GGG2CMC+G7
# 1           9GGG2CJ4+R5
# 2           9GGG2CPJ+X7
# 3           9GGG2CF3+HG
# 4           9GGG29RV+G7

# %%
df.sort_values(by = 'user_ratings_total', ignore_index = True, ascending = False)
# Out:
#                                                  name  \
# 0                                         Контакт Бар
# 1                                             Евразия
# 2                                          Golden Pub
# 3                                             Трибуна
# 4                                          Beer House
# 5                                  Feromon Grazhdanka
# 6                                     The Templet Bar
# 7                                        Fleet Street
# 8                                  Кальянная Mesa Bar
# 9                                          Pub Docker
# 10                                     Бар Два Ствола
# 11   LunaBar | Бар, кальян, караоке Калининский район
# 12                      пивной бутик Woodman bar&shop
# 13                                           КультБар
# 14  Бар-клуб Малина на метро Академическая Ӏ карао...
# 15                                        Бар Элегант
# 16                                 Пиf'ko street food
# 17                                            Escobar
# 18                                                Бар
# 19                                            Саппоро
#
#                                     formatted_address  rating  \
# 0        Коломяжский пр., 15, Санкт-Петербург, 197348     4.3
# 1   Граждaнский пр-т., 116к5, Санкт-Петербург, 195257     4.3
# 2   просп. Авиаторов Балтики, 7 к.1, Мурино, Ленин...     4.2
# 3    Граждaнский пр-т., 100Б, Санкт-Петербург, 195265     4.5
# 4      Граждaнский пр-т., 36, Санкт-Петербург, 195220     4.1
# 5            гражданский 119, Санкт-Петербург, 195267     4.0
# 6   пр. Просвещения, 76, к.1, Санкт-Петербург, 195297     4.4
# 7        ул. Бутлерова, 11/4, Санкт-Петербург, 195220     4.6
# 8   Гжатская ул., 22 к1, 1 этаж, Санкт-Петербург, ...     4.5
# 9      Гжатская ул., 22, к.4, Санкт-Петербург, 195220     4.6
# 10  Привокзальная пл., 3, 3A, Мурино, Ленинградска...     4.5
# 11  пр. Луначарского, 80 корпус 1В, Санкт-Петербур...     3.5
# 12       ул. Бутлерова, 9 к2, Санкт-Петербург, 195220     4.6
# 13  дом 76 корпус 2, пр. Луначарского, Санкт-Петер...     4.3
# 14     Граждaнский пр-т., 84, Санкт-Петербург, 195257     3.8
# 15         ул. Руставели, 66, Санкт-Петербург, 195299     4.6
# 16       Учительская ул., 18, Санкт-Петербург, 195269     4.1
# 17   Новая ул., 7, Мурино, Ленинградская обл., 188662     4.4
# 18     Гжатская ул., 22, к.4, Санкт-Петербург, 195220     5.0
# 19  пр. Просвещения, 80, корп. 2, лит. А, Санкт-Пе...     0.0
#
#                                                 types  user_ratings_total  \
# 0   [cafe, bar, food, point_of_interest, establish...                1451
# 1   [bar, restaurant, food, point_of_interest, est...                 921
# 2   [night_club, bar, restaurant, food, point_of_i...                 640
# 3   [restaurant, bar, food, point_of_interest, est...                 606
# 4   [bar, restaurant, food, point_of_interest, est...                 524
# 5   [movie_theater, night_club, cafe, bar, restaur...                 415
# 6   [bar, restaurant, food, point_of_interest, est...                 407
# 7   [bar, restaurant, food, point_of_interest, est...                 320
# 8   [cafe, bar, restaurant, food, point_of_interes...                 248
# 9             [bar, point_of_interest, establishment]                 219
# 10            [bar, point_of_interest, establishment]                 218
# 11  [night_club, bar, restaurant, food, point_of_i...                 214
# 12            [bar, point_of_interest, establishment]                 167
# 13  [bar, restaurant, food, point_of_interest, est...                 122
# 14  [bar, night_club, restaurant, food, point_of_i...                 117
# 15            [bar, point_of_interest, establishment]                  96
# 16  [bar, cafe, food, point_of_interest, establish...                  60
# 17  [bar, meal_delivery, meal_takeaway, restaurant...                   7
# 18            [bar, point_of_interest, establishment]                   3
# 19            [bar, point_of_interest, establishment]                   0
#
#     opening_hours.open_now  geometry.location.lat  geometry.location.lng
# 0                     True              60.002222              30.299167
# 1                     True              60.034615              30.417198
# 2                     True              60.051606              30.437939
# 3                     True              60.023930              30.403810
# 4                     True              60.010783              30.393956
# 5                     True              60.033868              30.420680
# 6                     True              60.041360              30.393235
# 7                     True              60.005876              30.404596
# 8                     True              60.011493              30.388371
# 9                     True              60.013220              30.388858
# 10                    True              60.052380              30.446487
# 11                    True              60.036292              30.374953
# 12                    True              60.011717              30.386928
# 13                    True              60.036900              30.364440
# 14                    True              60.016064              30.398434
# 15                    True              60.037469              30.430666
# 16                    True              60.032029              30.405459
# 17                    True              60.040650              30.446843
# 18                    True              60.013317              30.388640
# 19                    True              60.038575              30.409619

# %%
df = df[['name','formatted_address', 
             'rating', 'types', 'user_ratings_total', 
             'opening_hours.open_now',
            'geometry.location.lat', 'geometry.location.lng']]

# %%
bar = df.loc[df.name == 'Бар Элегант'].squeeze()
bar
# Out:
# name                                                     Бар Элегант
# formatted_address         ул. Руставели, 66, Санкт-Петербург, 195299
# rating                                                           4.6
# types                        [bar, point_of_interest, establishment]
# user_ratings_total                                                96
# opening_hours.open_now                                          True
# geometry.location.lat                                      60.037469
# geometry.location.lng                                      30.430666
# Name: 2, dtype: object

# %%
bar['rating']
# Out:
# 2    4.6
# Name: rating, dtype: float64

# %%
mes = ''
for i, ind in enumerate(df.sort_values('user_ratings_total', ascending = False)[:5].index):
    mes += f"{i}. {df.loc[ind, 'name']}\n"
print(mes)
# Out:
# 0. Контакт Бар
# 1. Евразия
# 2. Golden Pub
# 3. Трибуна
# 4. Beer House

# %%
serch = bar_serch.Bar_serch((30.419383,60.03081))

# %%
bar_info_df = gmaps.place(place_id = 'ChIJMcDmjUczlkYRR5iASDNGibU', language = 'ru')
bar_info_df
# Out:
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': 'Санкт-Петербург',
#     'short_name': 'СПБ',
#     'types': ['locality', 'political']},
#    {'long_name': 'Калининский',
#     'short_name': 'Калининский',
#     'types': ['administrative_area_level_3', 'political']},
#    {'long_name': 'Россия',
#     'short_name': 'RU',
#     'types': ['country', 'political']},
#    {'long_name': '195267', 'short_name': '195267', 'types': ['postal_code']}],
#   'adr_address': 'гражданский 119, <span class="locality">Санкт-Петербург</span>, <span class="country-name">Россия</span>, <span class="postal-code">195267</span>',
#   'business_status': 'OPERATIONAL',
#   'formatted_address': 'гражданский 119, Санкт-Петербург, Россия, 195267',
#   'formatted_phone_number': '8 (812) 969-77-77',
#   'geometry': {'location': {'lat': 60.033868, 'lng': 30.4206796},
#    'viewport': {'northeast': {'lat': 60.0351654802915,
#      'lng': 30.4219777302915},
#     'southwest': {'lat': 60.03246751970849, 'lng': 30.4192797697085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'international_phone_number': '+7 812 969-77-77',
#   'name': 'Feromon Grazhdanka',
#   'opening_hours': {'open_now': True,
#    'periods': [{'close': {'day': 1, 'time': '0600'},
#      'open': {'day': 0, 'time': '1100'}},
#     {'close': {'day': 2, 'time': '0600'}, 'open': {'day': 1, 'time': '1100'}},
#     {'close': {'day': 3, 'time': '0600'}, 'open': {'day': 2, 'time': '1100'}},
#     {'close': {'day': 4, 'time': '0600'}, 'open': {'day': 3, 'time': '1100'}},
#     {'close': {'day': 5, 'time': '0600'}, 'open': {'day': 4, 'time': '1100'}},
#     {'close': {'day': 6, 'time': '0600'}, 'open': {'day': 5, 'time': '1100'}},
#     {'close': {'day': 0, 'time': '0600'}, 'open': {'day': 6, 'time': '1100'}}],
#    'weekday_text': ['понедельник: 11:00–06:00',
#     'вторник: 11:00–06:00',
#     'среда: 11:00–06:00',
#     'четверг: 11:00–06:00',
#     'пятница: 11:00–06:00',
#     'суббота: 11:00–06:00',
#     'воскресенье: 11:00–06:00']},
#   'photos': [{'height': 1367,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109014582649891981536">Feromon na Grazhdanskom (Кальянная/Lounge бар/Тайм кафе СПБ)</a>'],
#     'photo_reference': 'Aap_uEBTMhT54R-uWrSrEs6p44jfgGqjdNWzsiqtb2hXYPrTqgjKu0WtyC623Hy7BGB-k7xyk0ItVmeBld2m7GrUyJde-CAXZnjVWMgZyKrWHfSABjCmHVvd99ALYkYsLgW9yuXSZpXRMPNRrt_w6Aghzil8GIhW7AZ3q96JhEGftldah7Rn',
#     'width': 2048},
#    {'height': 1459,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109014582649891981536">Feromon na Grazhdanskom (Кальянная/Lounge бар/Тайм кафе СПБ)</a>'],
#     'photo_reference': 'Aap_uEDuvZCRA3RFCVPjSQ4ZOlwsxYkjwQR3SoaKNjomxmgH-KCkU75ArXjqWpyXUIApVVcsNAGr7b7yAhvAiaSm9RyN6TjIkSKb8VjqXXqx6Qcw-hEuihdDAZ5u1jod7ciEisxATzoTSTJlcJDphyacrRcOG_jxTuWwSaz6gk-Zx4LxLtXK',
#     'width': 1122},
#    {'height': 1367,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109014582649891981536">Feromon na Grazhdanskom (Кальянная/Lounge бар/Тайм кафе СПБ)</a>'],
#     'photo_reference': 'Aap_uECiGNShkFPBsPNTXnrIhveJHVwTr-JUL4gLHhYSyaFAkdQroUswBCBECca5wTdEIMTZ28N-6Xd4zP-VotoCY2fD6ZrQ3ALRdxi0p_KvlIwglRX9LwKFS1J_pKOOf2eQjKJjNqPoNUa5c6sTQhPAUCk8ZK72yAggynqowPI41TMsM-wW',
#     'width': 2048},
#    {'height': 1280,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109014582649891981536">Feromon na Grazhdanskom (Кальянная/Lounge бар/Тайм кафе СПБ)</a>'],
#     'photo_reference': 'Aap_uEAtaJYaNdL4wEDFuKQPVHH4iEfe5eiCOdGmputTL28LYygLgUjPd8oP9CrW2FvY3UO59CFMQeyIgqDcJFIf_HrarxO74cWo_ILbATMOxYTEc5sRG0BXLcEgJXQD31JdEoLt-YE08E3pSsG99pMEQ3-CodwHkskgihl17BVM2jY3S5W_',
#     'width': 1920},
#    {'height': 3000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117924299005568371132">Наталья</a>'],
#     'photo_reference': 'Aap_uEBE4IQAYcwX7nX6-PGMGmdRTKDIhzpjAO2CIJFRpIQRhpNKeJQr0MQxiDJBooUCC_3YUBgSEuJ88ZQEqNkRUjdGZjwaHaqXblQVriozlYY6epoVhZ59AjZMvzbY_zSou-zy8raFlPTPMFky2mVaGv_1VCEZkzQLBR0AOFNJxcwLLvJp',
#     'width': 4000},
#    {'height': 853,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100409578929224935174">Feromon Group</a>'],
#     'photo_reference': 'Aap_uEAVdil-2EZfRH1xNArB7pxsoMjOYFrnU8s1W5RqxqtBqm1UXVTlrpPM-9QOKDd5EwhxnYCd_Dj4o5Eif1VQC-DljgQJ8ZvU7XqwVdMM0KOtL2DDBL_eIXHrJnBk5RNnj4ibmjZiAR6TPJWyOQWUUjvdwjX09CelsZgFg5ebcOjmt3h_',
#     'width': 1280},
#    {'height': 4128,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111742194471376560696">Юлия Ёлохова</a>'],
#     'photo_reference': 'Aap_uEBaMHO9ZRyrVuKjJgCvQI_UqC9Kin2YD0WiwneeLtOk1ugqCf8bfVId4CjXRZCEqFBJI8pTFSQ7B0B10m6uesVLLpCdt99IcF6j8kwSOlLS_B_FEzRSgknBK1X7eyjCrWosYkQhWQnQMeVYh_HHmW11jNMRQOw6tA_V5xGFRxzrmFE',
#     'width': 3096},
#    {'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107516304144600091979">Надежда Максимова</a>'],
#     'photo_reference': 'Aap_uECME3LWWWnyfVOyuJLvkJmxheAImMD3iiwmJdBs4nQ1Szo0WHGRz9WgNTNY8afkuLld42R-pfvfmHnLfGUckO92I6BCquQ0oVQfoGeSHmffADk9Q-wtl1J4XoHzuajUI-1U1M5Mj6iBTkxqW3_FkJin9xpxFlZtrIlS0drAGsx3w3g',
#     'width': 4032},
#    {'height': 1152,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111742194471376560696">Юлия Ёлохова</a>'],
#     'photo_reference': 'Aap_uECkNG8osG1ypWZb0tfl0a6dGNqywKAgmfInumMn6ag9WOIxLDyxoOCR_42uLTTH6iPHAdvsZaVTnOdZsRYCssZt9rtMhojfXGILxsP2wL18588j4YHjyExnzg5SEvfypOAQtWJ0Bnw2jtaYfH24bLTfuSO7YTfFgGF6Egr7EJUKgXw',
#     'width': 2048},
#    {'height': 1101,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109014582649891981536">Feromon na Grazhdanskom (Кальянная/Lounge бар/Тайм кафе СПБ)</a>'],
#     'photo_reference': 'Aap_uEDJJaqQxvjDgzssGDyAD11vygpup75QMMmh-51IWnvwJlHmqKoq37XQ1pTs-KS-0EngFmVxEOX-UPPELuT_DuZ2rym7vZ-yYGbDMbJKCcTZLg29-6oMPcB_M8NXFabHV1dzmWaqhY8y2qsfrDg8TWsLyCtGIESzJXahRwX18TJzVCXj',
#     'width': 1500}],
#   'place_id': 'ChIJMcDmjUczlkYRR5iASDNGibU',
#   'plus_code': {'compound_code': '2CMC+G7 Калининский район, Санкт-Петербург, Россия',
#    'global_code': '9GGG2CMC+G7'},
#   'price_level': 2,
#   'rating': 4,
#   'reference': 'ChIJMcDmjUczlkYRR5iASDNGibU',
#   'reviews': [{'author_name': 'Veronika Poklonskaya',
#     'author_url': 'https://www.google.com/maps/contrib/117779487591926034059/reviews',
#     'language': 'ru',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AOh14GjhXsDy2QsPmPXiR05bqbg95qluniS7deeV0Liruw=s128-c0x00000000-cc-rp-mo-ba2',
#     'rating': 1,
#     'relative_time_description': 'меньше недели назад',
#     'text': 'В общем, сегодня праздновали мой личный праздник: кальян, выпить и поесть. Буквально через минут пятнадцать кальян рухнул мне с сестрой на лицо; я обожгла пальцы скидывая угли с себя. Вместо извинения, предложили посмотреть камеры, мол, мы само неровно сели  мы предложили вызвать полицию, так её и не дождались, хотя сотрудники уверяли, что вызвали и весь счёт был оплачен. Прождали 50 минут, потом все просто разъехались',
#     'time': 1626135316},
#    {'author_name': 'Катя Левина',
#     'author_url': 'https://www.google.com/maps/contrib/101517502492231832443/reviews',
#     'language': 'ru',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AOh14GjeeBAmimhR14rSQ44jriWAKpjgMRn5SdD7fsb5eC4=s128-c0x00000000-cc-rp-mo-ba3',
#     'rating': 1,
#     'relative_time_description': '2 недели назад',
#     'text': '25.06.2021 ПЯТНИЦА, пришли на бизнес ланч,т.к. работаем в этом тц, ожидание бизнеса 50 минут, вместо напитка была предложена вода , салат принесли с ГРЯЗНОЙ КАПУСТОЙ да ещё и горький, суп-вода. Просидели 1,5 часа, предложилибонусом мороженное и то не то принесли что заказывали  - отвратительно!',
#     'time': 1624621406},
#    {'author_name': 'Александр Хадарин',
#     'author_url': 'https://www.google.com/maps/contrib/111507769901545494461/reviews',
#     'language': 'ru',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a-/AOh14Gh3cLR8UjqfbYZdBmjaOkVG8OwN5FmCOmH7zg-VfQ=s128-c0x00000000-cc-rp-mo-ba3',
#     'rating': 2,
#     'relative_time_description': '3 недели назад',
#     'text': 'Ужасная вонища кальяном во всем заведение, достаточно дорогое меню, для такого места, мало посетителей, что в принципе хорошо. На потолки лучше не смотреть! Отличный персонал, хорошие, вежливые официанты.был один раз, больше не пойду',
#     'time': 1624305460},
#    {'author_name': 'Анастасия Ширяева',
#     'author_url': 'https://www.google.com/maps/contrib/112388514275149947678/reviews',
#     'language': 'ru',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/AATXAJw3pudZdcyGAmSxEkOtZOywnSwTAKdq1PXQ4LLA=s128-c0x00000000-cc-rp-mo-ba3',
#     'rating': 1,
#     'relative_time_description': '2 месяца назад',
#     'text': 'Заведение не понравилось\nКальян заказали легкий, но по итогу приходилось звать кальянщика так как постоянно горчило, кальян предложили самый дорогой, цена не соответствует качеству. Цены в принципе выше среднего. Чай не вкусный, и так как официант когда подавал  наливал кипяток в чайник и сразу же разливал по кружка, ощущение что пьешь кипяток. Еда не самого лучшего качество, повторюсь что цена не соответствует качеству, так же за каждую позицию взимается плата по минутам, что тоже странно, не от общий стоимости, а на каждую позицию отдельно',
#     'time': 1619374691},
#    {'author_name': 'Егор «Deppsepp»',
#     'author_url': 'https://www.google.com/maps/contrib/117240226017397033006/reviews',
#     'language': 'ru',
#     'profile_photo_url': 'https://lh3.googleusercontent.com/a/AATXAJzbjrfbuRtUDupuUCbT8L1YTbCjpnSthfmLP4u7=s128-c0x00000000-cc-rp-mo',
#     'rating': 5,
#     'relative_time_description': 'месяц назад',
#     'text': 'Очень, очень вкусно...\nХорошие официанты.\nВключили фильм на свой вкус посмотрели.',
#     'time': 1623084114}],
#   'types': ['movie_theater',
#    'night_club',
#    'cafe',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'url': 'https://maps.google.com/?cid=13081063778747979847',
#   'user_ratings_total': 415,
#   'utc_offset': 180,
#   'vicinity': 'гражданский 119, Санкт-Петербург',
#   'website': 'https://feromon.group/institution/feromon-na-grazhdanskom/'},
#  'status': 'OK'}

# %%
reviews_df = pd.json_normalize(bar_info_df['result']['reviews'])
reviews_df
# Out:
#             author_name                                         author_url  \
# 0  Veronika Poklonskaya  https://www.google.com/maps/contrib/1177794875...
# 1           Катя Левина  https://www.google.com/maps/contrib/1015175024...
# 2     Александр Хадарин  https://www.google.com/maps/contrib/1115077699...
# 3     Анастасия Ширяева  https://www.google.com/maps/contrib/1123885142...
# 4       Егор «Deppsepp»  https://www.google.com/maps/contrib/1172402260...
#
#   language                                  profile_photo_url  rating  \
# 0       ru  https://lh3.googleusercontent.com/a-/AOh14GjhX...       1
# 1       ru  https://lh3.googleusercontent.com/a-/AOh14Gjee...       1
# 2       ru  https://lh3.googleusercontent.com/a-/AOh14Gh3c...       2
# 3       ru  https://lh3.googleusercontent.com/a/AATXAJw3pu...       1
# 4       ru  https://lh3.googleusercontent.com/a/AATXAJzbjr...       5
#
#   relative_time_description  \
# 0       меньше недели назад
# 1            2 недели назад
# 2            3 недели назад
# 3            2 месяца назад
# 4               месяц назад
#
#                                                 text        time
# 0  В общем, сегодня праздновали мой личный праздн...  1626135316
# 1  25.06.2021 ПЯТНИЦА, пришли на бизнес ланч,т.к....  1624621406
# 2  Ужасная вонища кальяном во всем заведение, дос...  1624305460
# 3  Заведение не понравилось\nКальян заказали легк...  1619374691
# 4  Очень, очень вкусно...\nХорошие официанты.\nВк...  1623084114

# %%
reviews_df[reviews_df.rating == reviews_df.rating.min()].text.values[0]
# Out:
# 'В общем, сегодня праздновали мой личный праздник: кальян, выпить и поесть. Буквально через минут пятнадцать кальян рухнул мне с сестрой на лицо; я обожгла пальцы скидывая угли с себя. Вместо извинения, предложили посмотреть камеры, мол, мы само неровно сели  мы предложили вызвать полицию, так её и не дождались, хотя сотрудники уверяли, что вызвали и весь счёт был оплачен. Прождали 50 минут, потом все просто разъехались'
